# %% [markdown]
# # What if we tracked win percentage on a rolling basis?

# %%
from pybaseball import *
import pandas as pd

# %%
dodgers24 = team_game_logs(2024, "CHC")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 dodgers24 = team_game_logs(2024, "CHC")
#
# File c:\Users\patri\Desktop\code\Baseball-Stats\.venv\lib\site-packages\pybaseball\cache\cache.py:58, in df_cache.__call__.<locals>._cached(*args, **kwargs)
#      55 result = self._safe_load_func_cache(func_data)
#      57 if result is None:
# ---> 58     result = func(*args, **kwargs)
#      59     if len(result) > 0:
#      60         self._safe_save_func_cache(func_data, result)
#
# File c:\Users\patri\Desktop\code\Baseball-Stats\.venv\lib\site-packages\pybaseball\team_game_logs.py:53, in team_game_logs(season, team, log_type)
#      51 if log_type not in ("batting", "pitching"):
#      52     raise ValueError("`log_type` must be either 'batting' or 'pitching'.")
# ---> 53 data = get_table(season, team, log_type)
#      54 data = postprocess(data)
# ...
